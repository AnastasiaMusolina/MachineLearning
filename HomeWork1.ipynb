# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('kc_house_data.csv', sep = ',', engine = 'python')

# %% [markdown]
# Датасет содержит цены продажи домов для округа Кинг, который включает Сиэтл. Он включает в себя дома, проданные в период с мая 2014 года по май 2015 года

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
print(data)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %% [markdown]
# #### Описание данных:
# 1. id - уникальный идентификатор для каждого проданного дома
# 2. data - дата продажи дома
# 3. price - цена
# 4. bedrooms - количество спален
# 5. bathrooms- количество ванных комнат, где 0.25 обозначает, что комната с туалетом, 0.5 - комната с туалетом и раковиной
# 6. sqft_living- жилая площадь
# 7. sqft_lot- площадь земельного участка
# 8. floors - количество этажей
# 9. waterfront - бинарная переменная, указывающая на то, есть ли вид на набережную
# 10. view - оценка внешнего вида дома от 0 до 4
# 11. condition - оценка состояния дома от 0 до 5
# 12. grade - оценка качества строительства и дизайна здания от 1 до 13
# 13. sqft_above - площадь дома отдельно без подвала
# 14. sqft_basement - площадь подвала
# 15. yr_built - год постройки
# 16. yr_renovated - год когда дом был отремонтарован или произведена реконструкция
# 17. zipcode - почтовый индекс
# 18. lat - широта
# 19. long - долгота
# 20. sqft_living15 - средняя общая площадь 15 ближайших домов

# %%
print(data.shape)
print(data.columns)
# Out:
# (21613, 21)
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=21613, step=1)

# %%
data.at[2,'date']
# Out:
# '20150225T000000'

# %%
data['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
data['date'][3]
# Out:
# '20141209T000000'

# %%
data['view'].dtype.name
# Out:
# 'int64'

# %%
type(data['id'][3])
# Out:
# numpy.int64

# %%
type(data['date'])
# Out:
# pandas.core.series.Series

# %%
data[['date', 'price']].head()
# Out:
#               date     price
# 0  20141013T000000  221900.0
# 1  20141209T000000  538000.0
# 2  20150225T000000  180000.0
# 3  20141209T000000  604000.0
# 4  20150218T000000  510000.0

# %% [markdown]
# Получим сводную информацию по количественным признакам:

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (25, 25))
pass

# %% [markdown]
# Матрица корреляции:

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plt.plot(data['sqft_living'], data['price'], 'o', alpha = 0.05)
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.title('sqft_living vs price')
pass

# %%
data['bedrooms'] == 2
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610     True
# 21611    False
# 21612     True
# Name: bedrooms, Length: 21613, dtype: bool

# %% [markdown]
# Построим диаграмму рассеяния

# %%
#Нарисуем диаграмму рассеяния для пары признаков lat и long
#450000 - среднее значение price в таблице

plt.figure(figsize=(20, 10))

plt.scatter(data['lat'][data['price'] >= 450000],
            data['long'][data['price'] >= 450000],
            alpha=0.2,
            color='red',
            label='> = 450000')

plt.scatter(data['lat'][data['price'] < 450000],
            data['long'][data['price'] < 450000],
            alpha=0.2,
            color='blue',
            label=' < 450000')

plt.xlabel('lat')
plt.ylabel('long')
plt.legend();

# %%
#450000 - среднее значение цены

plt.figure(figsize = (20, 15))

plt.scatter(data[data['price']<450000 ]['sqft_living'],
            data[data['price'] <450000 ]['sqft_lot'],
            alpha = 0.35,
            label = '< 450000',
            color = 'r')

plt.scatter(data[data['price']>=450000  ]['sqft_living'],
            data[data['price']>=450000 ]['sqft_lot'],
            alpha = 0.35,
            label = '>= 450000',
            color = 'b')

plt.xlabel('sqft_living')
plt.ylabel('sqft_lot')
plt.xlim(0, 10000)
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
data.describe(include = 'all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
data['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
data['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
for name in data['sqft_living'].unique():
    print(name, data['price'][data['sqft_living'] == name].iloc[0])
# Out:
# 1180 221900.0
# 2570 538000.0
# 770 180000.0
# 1960 604000.0
# 1680 510000.0
# 5420 1225000.0
# 1715 257500.0
# 1060 291850.0
# 1780 229500.0
# 1890 323000.0
# 3560 662500.0
# 1160 468000.0
# 1430 310000.0
# 1370 400000.0
# 1810 530000.0
# 2950 650000.0
# 1600 485000.0
# 1200 189000.0
# 1250 230000.0
# 1620 385000.0
# 3050 2000000.0
# 2270 285000.0
# 1070 252700.0
# 2450 329000.0
# 1710 233000.0
# 1400 667000.0
# 1520 438000.0
# 2320 580500.0
# 1190 280000.0
# 2330 687500.0
# 1090 535000.0
# 2060 322500.0
# 2300 696000.0
# 1660 550000.0
# 2360 640000.0
# 1220 240000.0
# 2620 605000.0
# 4220 775000.0
# 3595 861990.0
# 1570 685000.0
# 1280 309000.0
# 3160 488000.0
# 990 210490.0
# 2290 785000.0
# 2753 1350000.0
# 3150 345000.0
# 1410 600000.0
# 1980 585000.0
# 2730 920000.0
# 2830 885000.0
# 2250 292500.0
# 2420 301000.0
# 3250 951000.0
# 1850 430000.0
# 2150 650000.0
# 1260 289000.0
# 2519 505000.0
# 1540 549000.0
# 2770 317625.0
# 2720 975000.0
# 2240 287000.0
# 1000 204000.0
# ...

# %% [markdown]
# # Задача

# %% [markdown]
# Рассмотрим задачу прогнозирования цен на примере данного набора данных.
# Удалим признаки, не являющимися существенными: id, date, zipcode, lat, long, sqft_basement

# %%
data = data.drop('id', axis = 1)\
           .drop('date', axis = 1)

# %%
data
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %% [markdown]
# # Готовим данные

# %%
data['bathrooms'].dtype.name
# Out:
# 'float64'

# %%
data['waterfront'].dtype.name
# Out:
# 'int64'

# %% [markdown]
# Разделим столбцы на категориальные и числовые

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# []
# ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %% [markdown]
# Видим, что категориальные столбцы отсутствуют

# %% [markdown]
# # Обрабатываем пропущенные значения

# %%
data.median(axis = 0)
# Out:
# price            450000.0000
# bedrooms              3.0000
# bathrooms             2.2500
# sqft_living        1910.0000
# sqft_lot           7618.0000
# floors                1.5000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1560.0000
# sqft_basement         0.0000
# yr_built           1975.0000
# yr_renovated          0.0000
# zipcode           98065.0000
# lat                  47.5718
# long               -122.2300
# sqft_living15      1840.0000
# sqft_lot15         7620.0000
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)
data[numerical_columns].count(axis = 0)
# Out:
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %% [markdown]
# Пропущенных значений нет

# %% [markdown]
# # Векторизация

# %% [markdown]
# Так как в задаче отствуют категориальные (номинальными) признаками, то  векторизация не потребуется

# %% [markdown]
# # Нормализация количественных признаков

# %% [markdown]
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных. К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно нормализовать. Это можно делать разными способами. Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
price = data_numerical['price']
data_numerical = data_numerical.drop(('price'), axis = 1) 
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04
# mean   7.966196e-16  4.750304e-15  2.164660e-16  1.537582e-16 -7.674835e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.624320e+00 -2.745856e+00 -1.948846e+00 -3.521677e-01 -9.154058e-01
# 25%   -3.987279e-01 -4.736105e-01 -7.108783e-01 -2.430431e-01 -9.154058e-01
# 50%   -3.987279e-01  1.756026e-01 -1.849871e-01 -1.808034e-01  1.053914e-02
# 75%    6.764694e-01  5.002092e-01  5.118460e-01 -1.066855e-01  9.364841e-01
# max    3.185719e+01  7.641553e+00  1.247778e+01  3.950342e+01  3.714319e+00
#
#          waterfront          view     condition         grade    sqft_above  \
# count  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04
# mean  -1.172344e-15 -2.130659e-15 -1.305018e-14 -4.470126e-15 -6.304894e-16
# ...

# %% [markdown]
# ### Соединяем все в одну таблицу

# %%
data = pd.concat((price,data_numerical), axis = 1)
print(data.shape)
# Out:
# (21613, 19)

# %%
data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04
# mean   5.400881e+05  7.966196e-16  4.750304e-15  2.164660e-16  1.537582e-16
# std    3.671272e+05  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    7.500000e+04 -3.624320e+00 -2.745856e+00 -1.948846e+00 -3.521677e-01
# 25%    3.219500e+05 -3.987279e-01 -4.736105e-01 -7.108783e-01 -2.430431e-01
# 50%    4.500000e+05 -3.987279e-01  1.756026e-01 -1.849871e-01 -1.808034e-01
# 75%    6.450000e+05  6.764694e-01  5.002092e-01  5.118460e-01 -1.066855e-01
# max    7.700000e+06  3.185719e+01  7.641553e+00  1.247778e+01  3.950342e+01
#
#              floors    waterfront          view     condition         grade  \
# count  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04  2.161300e+04
# mean  -7.674835e-16 -1.172344e-15 -2.130659e-15 -1.305018e-14 -4.470126e-15
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('price'), axis = 1) # выбрасываем столбец 'price'
y = data['price']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X = X.to_numpy()

# %%
y = np.array(y <= 450000, dtype='int')

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (21613, 18)
# (21613,)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 15129 6484

# %%
15129+6484
# Out:
# 21613

# %% [markdown]
# # Метод kNN – $k$ ближайших соседей

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.10443519069337034 0.11582356570018507

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.11582356570018504

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[2938  300]
#  [ 451 2795]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# ### Подбор параметров

# %%
# Долго!
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.1236697732830987 15

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.10707911957168352 0.11536088834053054

# %% [markdown]
# # SVS

# %%
from sklearn.svm import SVC
svc = SVC(gamma='auto')
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.10185736003701501 0.10441085749537322

# %% [markdown]
# ### Подбор параметров

# %%
#очень долго
#from sklearn.model_selection import GridSearchCV
#Cs = 10.**np.arange(-5, 5)
#gamma_array = 10.**np.arange(-5, 5)
#svc = SVC(gamma='auto')
#grid = GridSearchCV(svc, cv=3, param_grid = {'C': Cs, 'gamma': gamma_array})
#grid.fit(X_train, y_train)

#best_cv_err = 1 - grid.best_score_
#best_C = grid.best_estimator_.C
#print(best_cv_err, best_C)

# %%
#svc = SVC(C = best_C, gamma='auto').fit(X_train, y_train)

#err_train = np.mean(y_train != knn.predict(X_train))
#err_test  = np.mean(y_test  != knn.predict(X_test))

#print(err_train, err_test)

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0014541608830722455 0.08682911782850093

# %% [markdown]
# ## Значимость признаков

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature '  lat' (0.298672)
#  2. feature 'sqft_living' (0.125671)
#  3. feature 'grade' (0.098928)
#  4. feature 'sqft_living15' (0.080342)
#  5. feature 'sqft_above' (0.063691)
#  6. feature ' long' (0.052264)
#  7. feature 'sqft_lot15' (0.046042)
#  8. feature 'sqft_lot' (0.044533)
#  9. feature 'yr_built' (0.043004)
# 10. feature 'zipcode' (0.042676)
# 11. feature 'bathrooms' (0.032046)
# 12. feature 'sqft_basement' (0.023627)
# 13. feature 'bedrooms' (0.013732)
# 14. feature 'floors' (0.011114)
# 15. feature ' view' (0.010350)
# 16. feature 'condition' (0.009020)
# 17. feature 'yr_renovated' (0.002977)
# 18. feature 'waterfront' (0.001307)

# %%
feature_names[[1, 0, 1]]
# Out:
# Index(['bathrooms', 'bedrooms', 'bathrooms'], dtype='object')

# %%
d_first = 18
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 18)

# %% [markdown]
# # Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0014541608830722455 0.08960518198642813

# %% [markdown]
# # AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0822261881155397 0.09330660086366441

# %% [markdown]
# # GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)
err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.03595743274505916 0.0851326341764343

# %% [markdown]
# # PCA - Метод главных компонент
#
# Применить PCA для сокращения размерности пространства признаков. Изобразить точки, сократив размерность пространства до 2. К новым данным применить классификатор ближайших соседей (с наилучшим значением к-ва соседей, полученнных ранее). Построить графики зависимости ошибки на тестовой и обучающей выборки в зависимости от количества используемых компонент. Найти наилучшее значение количества используемых главных компонент.

# %%
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
pca = PCA(n_components = 2)
pca.fit(X)
X_pca= pca.transform(X)
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size = 0.3, random_state = 42)
knn = KNeighborsClassifier(n_neighbors = 15).fit(X_train_pca, y_train_pca)
err_train = np.mean(y_train_pca != knn.predict(X_train_pca))
err_test  = np.mean(y_test_pca  != knn.predict(X_test_pca))
print(err_train,err_test)
# Out:
# 0.20847379205499372 0.23627390499691547

# %% [markdown]
# Ранее были получены ошибки 0.10707911957168352 0.11536088834053054

# %%
0.23627390499691547-0.11536088834053054
# Out:
# 0.12091301665638493

# %% [markdown]
# При уменьшении компонент до 2 получили ошибку на тестовой выборке больше на 0.12091301665638493

# %%
from sklearn.decomposition import PCA
err_train_pca = []
err_test_pca = []
pca_range = range(1, 19)
for k in pca_range:
    pca = PCA(n_components = k)
    pca.fit(X)
    X_pca = pca.transform(X)
    X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size = 0.3, random_state = 42)
    knn_model = KNeighborsClassifier(n_neighbors = 15).fit(X_train_pca, y_train_pca)
    err_train_pca.append(np.mean(knn_model.predict(X_train_pca)!=y_train_pca ))
    err_test_pca.append(np.mean(y_test_pca != knn_model.predict(X_test_pca)))
#X_pca = pca.transform(X) # или сразу pca.fit_transform(X)
#X_pca.shape

# %%
plt.plot(pca_range, err_train_pca, '.-r', label = 'Train error')
plt.plot(pca_range, err_test_pca,  '.-b', label = 'Test error')    
plt.legend(loc = 2)
plt.title('pca')
plt.xlabel('components')
plt.ylabel('error')
plt.xlim([18, 1])
# Out:
# (18, 1)

# %%
err_train_min = np.min(err_train_pca)
err_test_min = np.min(err_test_pca)
print(err_train_min, err_test_min)
# Out:
# 0.10152686892722586 0.1067242442936459

# %% [markdown]
# Наилучшее значение количества используемых главных компонент на тестовой выборке

# %%
print(err_test_pca.index(err_test_min) + 1)
# Out:
# 12

# %%
0.11536088834053054-0.1067242442936459
# Out:
# 0.008636644046884648

# %% [markdown]
# Ранее в kNN при количестве соседей = 15 были получены ошибки: 0.10707911957168352 0.11536088834053054

# %% [markdown]
# Видим, что при применении метода РСА ошибка на тестовой выборке уменьшилась на 0.008636644046884648, наименьшая ошибка достигается при количестве компонент = 12.

# %% [markdown]
# # Полносвязная (неглубокая) нейронная сеть

# %% [markdown]
# ### Обучаем классификатор

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# ### Проверяем качество классификатора

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %% [markdown]
# Ошибки на обучающей и тестовой выборках:

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.07138607971445568 0.09068476249228871

# %% [markdown]
# Другой способ:

# %%
print(mlp_model.score(X_train, y_train), mlp_model.score(X_test, y_test))
# Out:
# 0.9286139202855443 0.9093152375077113

# %%
print(1 - mlp_model.score(X_test, y_test))
# Out:
# 0.09068476249228874

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# Подберем оптимальное значение параметра регуляризации alpha

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.06920483838984731 0.08744602097470697

# %% [markdown]
# Оптимальное значение alpha:

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt[0])
# Out:
# 1.0

# %%
alpha_opt = alpha_opt[0]

# %% [markdown]
# ### Классификатор при найденном оптимальном значении alpha:

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred),np.mean(y_test != y_test_pred))
# Out:
# 0.07832639302002777 0.08744602097470697

# %% [markdown]
# Получаем,что ошибка на тестовой выборке немного больше ошибки на тренировочной выборке.
# Следовательно, наблюдаем переобучение даже с оптимальным значением alpha

# %% [markdown]
# # Random forests

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0014541608830722455 0.08837137569401604

# %% [markdown]
# Ошибка на тренировочной выборке меньше ошибки на тестовой, следовательно, наблюдаем переобучение

# %% [markdown]
# Построим график зависимости ошибки (на тестовой и обучающейся выборках и oob-ошибку) от количества используемых деревьев

# %%
trees_arr = np.arange(100, 1000, 100)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier (n_estimators = trees, oob_score=True, random_state=42)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)
    
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'y-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('Trees')
plt.ylabel('Error')
plt.legend()
pass

# %%
print(np.min(train_err), np.min(test_err))
# Out:
# 0.0014541608830722455 0.08729179518815545

# %% [markdown]
# Переобучение осталось

# %% [markdown]
# # Gradient boosted trees

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.03595743274505916 0.08482418260333127

# %% [markdown]
# Наблюдаем переобучение

# %%
trees_arr = np.arange(100, 1000, 100)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
print(np.min(train_err), np.min(test_err))
# Out:
# 0.040121620728402405 0.08359037631091919

# %% [markdown]
# Наблюдаем переобучение
